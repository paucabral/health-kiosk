# %% [markdown]
# Importing the necessary libraries.

# %%
import csv
import numpy as np
import pandas as pd
from collections import defaultdict
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Load the CSV for UMLS code and symptom pairs.

# %%
CSV_FILEPATH = 'dataset/disease-umls-code_pairs.csv'
data = pd.read_csv(CSV_FILEPATH)
data
# Out:
#          umls                    disease
# 0    C0020538       hypertensive disease
# 1    C0011847                   diabetes
# 2    C0011570          depression mental
# 3    C0011581        depressive disorder
# 4    C0010054  coronary arteriosclerosis
# ..        ...                        ...
# 144  C1258215                      ileus
# 145  C0001511                   adhesion
# 146  C0011253                   delusion
# 147  C0233472              affect labile
# 148  C0011127            decubitus ulcer
#
# [149 rows x 2 columns]

# %% [markdown]
# Extract the entries to lists.

# %%
disease_names = data['disease'].tolist()
disease_codes = data['umls'].tolist()

# %% [markdown]
# Scraping data from <a href="https://www.ncbi.nlm.nih.gov/medgen/">NCBI MedGen</a> for description on each disease based on UMLS code.

# %%
ROOT_URL = 'https://www.ncbi.nlm.nih.gov/medgen/'
disease_data = []

for disease_name, term in zip(disease_names, disease_codes):

    scraped_url = "{}?term={}".format(ROOT_URL, term)
    r = requests.get(scraped_url)

    soup = BeautifulSoup(r.content, 'html5lib')
    disease_info = soup.find("div", {"class": "portlet_content ln"})
    if disease_info:
        description = disease_info.text.replace('\xa0', ' ')
        if disease_info.find("a"):
            source_name = disease_info.find("a").text
            source_link = disease_info.find("a")['href']
        else:
            source_name = None
            source_link = None
    else:
        description = None
        source_name = None
        source_link = None

    entry = {
        "disease": disease_name,
        "code": term,
        "description": description,
        "source_name": source_name,
        "source_link": source_link,
        "root_url": scraped_url
    }

    disease_data.append(entry)

# %% [markdown]
# Preview of the generated dictionary from scraping.

# %%
disease_data
# Out:
# [{'disease': 'hypertensive disease',
#   'code': 'C0020538',
#   'description': 'The presence of chronic increased pressure in the systemic arterial system. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0020538'},
#  {'disease': 'diabetes',
#   'code': 'C0011847',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0011847'},
#  {'disease': 'depression mental',
#   'code': 'C0011570',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0011570'},
#  {'disease': 'depressive disorder',
#   'code': 'C0011581',
#   'description': 'Frequent feelings of being down, miserable, and/or hopeless; difficulty recovering from such moods; pessimism about the future; pervasive shame; feeling of inferior self-worth; thoughts of suicide and suicidal behavior. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0011581'},
#  {'disease': 'coronary arteriosclerosis',
#   'code': 'C0010054',
#   'description': 'Reduction of the diameter of the coronary arteries as the result of an accumulation of atheromatous plaques within the walls of the coronary arteries, which increases the risk of myocardial ischemia. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0010054'},
#  {'disease': 'coronary heart disease',
#   'code': 'C0010068',
#   'description': 'An imbalance between myocardial functional requirements and the capacity of the CORONARY VESSELS to supply sufficient blood flow. It is a form of MYOCARDIAL ISCHEMIA (insufficient blood supply to the heart muscle) caused by a decreased capacity of the coronary vessels. [from MeSH]',
#   'source_name': 'MeSH',
#   'source_link': 'http://www.nlm.nih.gov/pubs/factsheets/mesh.html',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0010068'},
#  {'disease': 'pneumonia',
#   'code': 'C0032285',
#   'description': 'Inflammation of any part of the lung parenchyma. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0032285'},
#  {'disease': 'failure heart congestive',
#   'code': 'C0018802',
#   'description': 'The presence of an abnormality of cardiac function that is responsible for the failure of the heart to pump blood at a rate that is commensurate with the needs of the tissues or a state in which abnormally elevated filling pressures are required for the heart to do so. Heart failure is frequently related to a defect in myocardial contraction. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0018802'},
#  {'disease': 'accident cerebrovascular',
#   'code': 'C0038454',
#   'description': 'Sudden impairment of blood flow to a part of the brain due to occlusion or rupture of an artery to the brain. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0038454'},
#  {'disease': 'asthma',
#   'code': 'C0004096',
#   'description': 'Asthma is characterized by increased responsiveness of the tracheobronchial tree to multiple stimuli, leading to narrowing of the air passages with resultant dyspnea, cough, and wheezing. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0004096'},
#  {'disease': 'myocardial infarction',
#   'code': 'C0027051',
#   'description': 'Necrosis of the myocardium caused by an obstruction of the blood supply to the heart and often associated with chest pain, shortness of breath, palpitations, and anxiety as well as characteristic EKG findings and elevation of serum markers including creatine kinase-MB fraction and troponin. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0027051'},
#  {'disease': 'hypercholesterolemia',
#   'code': 'C0020443',
#   'description': 'An increased concentration of cholesterol in the blood. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0020443'},
#  {'disease': 'infection',
#   'code': 'C0021311',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0021311'},
#  {'disease': 'infection urinary tract',
#   'code': 'C0042029',
#   'description': 'A bacterial infectious process affecting any part of the urinary tract, most commonly the bladder and the urethra. Symptoms include urinary urgency and frequency, burning sensation during urination, lower abdominal discomfort, and cloudy urine. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0042029'},
#  {'disease': 'anemia',
#   'code': 'C0002871',
#   'description': 'A reduction in erythrocytes volume or hemoglobin concentration. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0002871'},
#  {'disease': 'chronic obstructive airway disease',
#   'code': 'C0024117',
#   'description': 'Chronic obstructive pulmonary disease (COPD) is a common, complex disorder associated with substantial morbidity and mortality. COPD is defined by irreversible airflow obstruction due to chronic bronchitis, emphysema, and/or small airways disease. Airflow obstruction is typically determined by reductions in quantitative spirometric indices, including forced expiratory volume at 1 second (FEV1) and the ratio of FEV1 to forced vital capacity (FVC) (Silverman et al., 2002; Celedon et al., 2004). [from OMIM]',
#   'source_name': 'OMIM',
#   'source_link': 'http://www.omim.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0024117'},
#  {'disease': 'dementia',
#   'code': 'C0497327',
#   'description': 'A loss of global cognitive ability of sufficient amount to interfere with normal social or occupational function. Dementia represents a loss of previously present cognitive abilities, generally in adults, and can affect memory, thinking, language, judgment, and behavior. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0497327'},
#  {'disease': 'insufficiency renal',
#   'code': 'C1565489',
#   'description': 'A reduction in the level of performance of the kidneys in areas of function comprising the concentration of urine, removal of wastes, the maintenance of electrolyte balance, homeostasis of blood pressure, and calcium metabolism. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C1565489'},
#  {'disease': 'confusion',
#   'code': 'C0009676',
#   'description': 'Lack of clarity and coherence of thought, perception, understanding, or action. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0009676'},
#  {'disease': 'degenerative polyarthritis',
#   'code': 'C0029408',
#   'description': 'Osteoarthritis (OA) is a degenerative disease of the joints characterized by degradation of the hyaline articular cartilage and remodeling of the subchondral bone with sclerosis (Meulenbelt et al., 2006). Clinical problems include pain and joint stiffness often leading to significant disability and joint replacement. Osteoarthritis exhibits a clear predilection for specific joints; it appears most commonly in the hip and knee joints and lumbar and cervical spine, as well as in the distal interphalangeal and the first carpometacarpal (base of thumb) and proximal interphalangeal joints of the hand; however, patients with osteoarthritis may have 1, a few, or all of these sites affected (Stefansson et al., 2003). According to a conservative estimate, greater than 70% of the population of the United States at age 65 years is affected by the disease, reflecting its age dependence.\r Genetic Heterogeneity of Susceptibility to Osteoarthritis\r Susceptibility to osteoarthritis has been associated with variation in other genes: OS2 (140600) with variation in the MATN3 gene (602109) on chromosome 2p24; OS3 (607850) with variation in the ASPN gene (608135) on chromosome 9q22; and OS5 (612400) with variation in the GDF5 gene (601146) on chromosome 20q11.\r Other susceptibility loci for osteoarthritis have been mapped to chromosomes 2q33 (OS4; 610839) and 3p24 (OS6; 612401). [from OMIM]',
#   'source_name': 'OMIM',
#   'source_link': 'http://www.omim.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0029408'},
#  {'disease': 'hypothyroidism',
#   'code': 'C0020676',
#   'description': 'Deficiency of thyroid hormone. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0020676'},
#  {'disease': 'anxiety state',
#   'code': 'C0700613',
#   'description': 'Etiology\nThe status of anxiety state among cancer patients and their relatives during coronavirus disease 2019 (COVID-19) in Hubei, China.\nYang S,\nYao H,\nSong Y,\nShu C,\nChen M,\nPi G,\nJin M,\nChen R,\nWang Q,\nChang J,\nZuo Z,\nHu J\nAnn Palliat Med\n2021 Apr;10(4):4601-4611.\ndoi: 10.21037/apm-21-745.\nPMID: 33966408\n\nRelaxation with heat and procedural information to diminish anxiety in presurgical patients of hernia surgery.\nAceituno-Ríos AM,\nPalomera-Chávez A,\nDomínguez-Salcido I,\nFlores-Ríos JA,\nBrambila-Tapia AJL\nPsychol Health Med\n2020 Oct;25(9):1137-1143.\nEpub 2020 Mar 3\ndoi: 10.1080/13548506.2020.1734217.\nPMID: 32125184\n\nAssociation between anxiety state and mitral valve disorders: A Taiwanese population-wide observational study.\nDubey NK,\nSyed-Abdul S,\nNguyen PA,\nDubey R,\nIqbal U,\nLi YC,\nChen WH,\nDeng WP\nComput Methods Programs Biomed\n2016 Aug;132:57-61.\nEpub 2016 Apr 21\ndoi: 10.1016/j.cmpb.2016.04.018.\nPMID: 27282227\n\nEffects of acupuncture with meridian acupoints and three Anmian acupoints on insomnia and related depression and anxiety state.\nHuo ZJ,\nGuo J,\nLi D\nChin J Integr Med\n2013 Mar;19(3):187-91.\nEpub 2012 Aug 18\ndoi: 10.1007/s11655-012-1240-6.\nPMID: 22903446\n\nRelationship of anxiety state with lymphocyte subsets and the effect of Chinese medical treatment on anxiety in patients with chronic hepatitis B.\nLiu WJ,\nZhang YH,\nJiang HY\nChin J Integr Med\n2011 Apr;17(4):302-6.\nEpub 2011 Apr 21\ndoi: 10.1007/s11655-011-0708-0.\nPMID: 21509675\nSee all (385)\nDiagnosis\nPrevalence of Temporomandibular Disorders and Anxiety State Levels in Ballet Dancers A Cross-Sectional Study.\nHilgenberg-Sydney PB,\nWilhelm JM,\nPimentel G,\nPetterle R,\nBonotto D\nJ Dance Med Sci\n2020 Jun 15;24(2):88-92.\ndoi: 10.12678/1089-313X.24.2.88.\nPMID: 32456763\n\nCould White Coat Ocular Hypertension Affect to the Accuracy of the Diagnosis of Glaucoma? Relationships Between Anxiety and Intraocular Pressure in a Simulated Clinical Setting.\nMéndez-Ulrich JL,\nSanz A,\nFeliu-Soler A,\nÁlvarez M,\nBorràs X\nAppl Psychophysiol Biofeedback\n2018 Mar;43(1):49-56.\ndoi: 10.1007/s10484-017-9385-x.\nPMID: 29119282\n\nEffects of ascorbic acid on anxiety state and affect in a non-clinical sample.\nMoritz B,\nSchwarzbold ML,\nGuarnieri R,\nDiaz AP,\nS Rodrigues AL,\nDafre AL\nActa Neurobiol Exp (Wars)\n2017;77(4):362-372.\nPMID: 29369301\n\nUsing Mobile Sensing to Test Clinical Models of Depression, Social Anxiety, State Affect, and Social Isolation Among College Students.\nChow PI,\nFua K,\nHuang Y,\nBonelli W,\nXiong H,\nBarnes LE,\nTeachman BA\nJ Med Internet Res\n2017 Mar 3;19(3):e62.\ndoi: 10.2196/jmir.6820.\nPMID: 28258049Free PMC Article\n\nDetection of stress/anxiety state from EEG features during video watching.\nGiannakakis G,\nGrigoriadis D,\nTsiknakis M\nAnnu Int Conf IEEE Eng Med Biol Soc\n2015;2015:6034-7.\ndoi: 10.1109/EMBC.2015.7319767.\nPMID: 26737667\nSee all (223)\nTherapy\nRelaxation with heat and procedural information to diminish anxiety in presurgical patients of hernia surgery.\nAceituno-Ríos AM,\nPalomera-Chávez A,\nDomínguez-Salcido I,\nFlores-Ríos JA,\nBrambila-Tapia AJL\nPsychol Health Med\n2020 Oct;25(9):1137-1143.\nEpub 2020 Mar 3\ndoi: 10.1080/13548506.2020.1734217.\nPMID: 32125184\n\nEffects of ascorbic acid on anxiety state and affect in a non-clinical sample.\nMoritz B,\nSchwarzbold ML,\nGuarnieri R,\nDiaz AP,\nS Rodrigues AL,\nDafre AL\nActa Neurobiol Exp (Wars)\n2017;77(4):362-372.\nPMID: 29369301\n\nEffects of acupuncture with meridian acupoints and three Anmian acupoints on insomnia and related depression and anxiety state.\nHuo ZJ,\nGuo J,\nLi D\nChin J Integr Med\n2013 Mar;19(3):187-91.\nEpub 2012 Aug 18\ndoi: 10.1007/s11655-012-1240-6.\nPMID: 22903446\n\nRelationship of anxiety state with lymphocyte subsets and the effect of Chinese medical treatment on anxiety in patients with chronic hepatitis B.\nLiu WJ,\nZhang YH,\nJiang HY\nChin J Integ ...
#   'source_name': 'The status of anxiety state among cancer patients and their relatives during coronavirus disease 2019 (COVID-19) in Hubei, China.',
#   'source_link': '/pubmed/33966408',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0700613'},
#  {'disease': 'malignant neoplasms',
#   'code': 'C0006826',
#   'description': 'A tumor composed of atypical neoplastic, often pleomorphic cells that invade other tissues. Malignant neoplasms often metastasize to distant anatomic sites and may recur after excision. The most common malignant neoplasms are carcinomas, Hodgkin and non-Hodgkin lymphomas, leukemias, melanomas, and sarcomas. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0006826'},
#  {'disease': 'primary malignant neoplasm',
#   'code': 'C1306459',
#   'description': 'A malignant tumor at the original site of growth. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C1306459'},
#  {'disease': 'acquired immuno-deficiency syndrome',
#   'code': 'C0001175',
#   'description': 'A syndrome resulting from the acquired deficiency of cellular immunity caused by the human immunodeficiency virus (HIV). It is characterized by the reduction of the Helper T-lymphocytes in the peripheral blood and the lymph nodes. Symptoms include generalized lymphadenopathy, fever, weight loss, and chronic diarrhea. Patients with AIDS are especially susceptible to opportunistic infections (usually pneumocystis carinii pneumonia, cytomegalovirus (CMV) infections, tuberculosis, candida infections, and cryptococcosis), and the development of malignant neoplasms (usually non-Hodgkin lymphoma and Kaposi sarcoma). The human immunodeficiency virus is transmitted through sexual contact, sharing of contaminated needles, or transfusion of contaminated blood. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0001175'},
#  {'disease': 'HIV',
#   'code': 'C0019682',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0019682'},
#  {'disease': 'hiv infections',
#   'code': 'C0019693',
#   'description': 'An infection caused by the human immunodeficiency virus. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0019693'},
#  {'disease': 'cellulitis',
#   'code': 'C0007642',
#   'description': 'A bacterial infection and inflammation of the skin und subcutaneous tissues. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0007642'},
#  {'disease': 'gastroesophageal reflux disease',
#   'code': 'C0017168',
#   'description': 'Gastroesophageal reflux (GER) is characterized by the retrograde movement of stomach contents into the esophagus. In its most severe form, GER results in extensive tissue damage caused by acid reflux. In adolescents and adults, and even infrequently in children, chronic GER is associated with the risk of developing Barrett metaplasia (614266), a premalignant lesion of the esophageal mucosa (Hu et al., 2000). In turn, Barrett metaplasia is correlated with the development of adenocarcinoma of the esophagus (see 614266), estimated as the fifth most prevalent neoplasia in the Western world (Lagergren et al., 1999). [from OMIM]',
#   'source_name': 'OMIM',
#   'source_link': 'http://www.omim.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0017168'},
#  {'disease': 'septicemia',
#   'code': 'C0036690',
#   'description': 'Systemic inflammatory response to infection. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0036690'},
#  {'disease': 'systemic infection',
#   'code': 'C0243026',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0243026'},
#  {'disease': 'sepsis (invertebrate)',
#   'code': 'C1090821',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C1090821'},
#  {'disease': 'deep vein thrombosis',
#   'code': 'C0149871',
#   'description': 'Formation of a blot clot in a deep vein. The clot often blocks blood flow, causing swelling and pain. The deep veins of the leg are most often affected. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0149871'},
#  {'disease': 'dehydration',
#   'code': 'C0011175',
#   'description': 'A condition resulting from the excessive loss of water from the body. It is usually caused by severe diarrhea, vomiting or diaphoresis. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0011175'},
#  {'disease': 'neoplasm',
#   'code': 'C0027651',
#   'description': 'An organ or organ-system abnormality that consists of uncontrolled autonomous cell-proliferation which can occur in any part of the body as a benign or malignant neoplasm (tumour). [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0027651'},
#  {'disease': 'embolism pulmonary',
#   'code': 'C0034065',
#   'description': 'An embolus (that is, an abnormal particle circulating in the blood) located in the pulmonary artery and thereby blocking blood circulation to the lung. Usually the embolus is a blood clot that has developed in an extremity (for instance, a deep venous thrombosis), detached, and traveled through the circulation before becoming trapped in the pulmonary artery. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0034065'},
#  {'disease': 'epilepsy',
#   'code': 'C0014544',
#   'description': 'A disorder characterized by recurrent seizures. [from SNOMEDCT_US]',
#   'source_name': 'SNOMEDCT_US',
#   'source_link': 'http://www.nlm.nih.gov/research/umls/Snomed/us_edition.html',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0014544'},
#  {'disease': 'cardiomyopathy',
#   'code': 'C0878544',
#   'description': 'A myocardial disorder in which the heart muscle is structurally and functionally abnormal, in the absence of coronary artery disease, hypertension, valvular disease and congenital heart disease sufficient to cause the observed myocardial abnormality. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0878544'},
#  {'disease': 'chronic kidney failure',
#   'code': 'C0022661',
#   'description': 'Impairment of the renal function due to chronic kidney damage. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0022661'},
#  {'disease': 'carcinoma',
#   'code': 'C0007097',
#   'description': 'A malignant tumor arising from epithelial cells. Carcinomas that arise from glandular epithelium are called adenocarcinomas, those that arise from squamous epithelium are called squamous cell carcinomas, and those that arise from transitional epithelium are called transitional cell carcinomas (NCI Thesaurus). [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0007097'},
#  {'disease': 'hepatitis C',
#   'code': 'C0019196',
#   'description': 'A viral infection caused by the hepatitis C virus. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0019196'},
#  {'disease': 'peripheral vascular disease',
#   'code': 'C0085096',
#   'description': 'This concept is primitive because within clinical practice it is used in different contexts to refer to both arteries and veins of the periphery or exclusively of peripheral arteries and sometimes to describe just occlusive disease of the peripheral arteries. More detailed unambiguous concepts are available for these more specific interpretations. [from SNOMEDCT_US]',
#   'source_name': 'SNOMEDCT_US',
#   'source_link': 'http://www.nlm.nih.gov/research/umls/Snomed/us_edition.html',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0085096'},
#  {'disease': 'psychotic disorder',
#   'code': 'C0033975',
#   'description': 'A condition characterized by changes of personality and thought patterns often accompanied by hallucinations and delusional beliefs. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0033975'},
#  {'disease': 'hyperlipidemia',
#   'code': 'C0020473',
#   'description': 'An elevated lipid concentration in the blood. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0020473'},
#  {'disease': 'bipolar disorder',
#   'code': 'C0005586',
#   'description': 'A disorder of the brain that causes unusual shifts in mood, energy, activity levels and the ability to carry out day-to-day tasks. Often these moods range and shift from periods of elation and energized behavior to those of hopelessness and depression. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0005586'},
#  {'disease': 'obesity',
#   'code': 'C0028754',
#   'description': 'Accumulation of substantial excess body fat. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0028754'},
#  {'disease': 'ischemia',
#   'code': 'C0022116',
#   'description': 'Lack of blood supply to an area of the body, resulting in impairment of tissue oxygenation. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0022116'},
#  {'disease': 'cirrhosis',
#   'code': 'C1623038',
#   'description': 'Etiology\nIn-patient Expenditure Between 2012 and 2020 Concerning Patients With Liver Cirrhosis in Chongqing: A Hospital-Based Multicenter Retrospective Study.\nTan J,\nTang X,\nHe Y,\nXu X,\nQiu D,\nChen J,\nZhang Q,\nZhang L\nFront Public Health\n2022;10:780704.\nEpub 2022 Mar 8\ndoi: 10.3389/fpubh.2022.780704.\nPMID: 35350474Free PMC Article\n\nA practical nomogram based on systemic inflammatory markers for predicting portal vein thrombosis in patients with liver cirrhosis.\nXing Y,\nTian Z,\nJiang Y,\nGuan G,\nNiu Q,\nSun X,\nHan R,\nJing X\nAnn Med\n2022 Dec;54(1):302-309.\ndoi: 10.1080/07853890.2022.2028893.\nPMID: 35060835Free PMC Article\n\nAssociation between liver cirrhosis and peri-implant diseases: a case-control study on implant- and patient-related risk factors.\nCosta FO,\nCortelli SC,\nCortelli JR,\nLages EJP,\nPereira GHM,\nCosta AM,\nCota LOM\nClin Oral Investig\n2022 Apr;26(4):3563-3572.\nEpub 2021 Dec 2\ndoi: 10.1007/s00784-021-04324-6.\nPMID: 34859326\n\nProthrombin Complex Concentrate Use in Intracranial Hemorrhage Patients With Cirrhosis Not on Prior Anticoagulation.\nSmall C,\nAttridge RL,\nFranco-Martinez C,\nDonnelly J,\nBarthol C\nJ Intensive Care Med\n2022 May;37(5):633-640.\nEpub 2021 May 4\ndoi: 10.1177/08850666211012650.\nPMID: 33942655\n\nImpact of spontaneous splenorenal shunt on liver volume and long-term survival of liver cirrhosis.\nYi F,\nGuo X,\nWang L,\nXu X,\nAn Y,\nTang Y,\nZhang W,\nTacke F,\nArora A,\nQi X\nJ Gastroenterol Hepatol\n2021 Jun;36(6):1694-1702.\nEpub 2021 Jan 14\ndoi: 10.1111/jgh.15386.\nPMID: 33393106\nSee all (41573)\nDiagnosis\nIn-patient Expenditure Between 2012 and 2020 Concerning Patients With Liver Cirrhosis in Chongqing: A Hospital-Based Multicenter Retrospective Study.\nTan J,\nTang X,\nHe Y,\nXu X,\nQiu D,\nChen J,\nZhang Q,\nZhang L\nFront Public Health\n2022;10:780704.\nEpub 2022 Mar 8\ndoi: 10.3389/fpubh.2022.780704.\nPMID: 35350474Free PMC Article\n\nA practical nomogram based on systemic inflammatory markers for predicting portal vein thrombosis in patients with liver cirrhosis.\nXing Y,\nTian Z,\nJiang Y,\nGuan G,\nNiu Q,\nSun X,\nHan R,\nJing X\nAnn Med\n2022 Dec;54(1):302-309.\ndoi: 10.1080/07853890.2022.2028893.\nPMID: 35060835Free PMC Article\n\nAssociation of tumor necrosis factor-α inhibitors and liver cirrhosis in patients with rheumatoid arthritis: A nationwide population-based nested case-control study.\nChen DY,\nLin CH,\nChen HH,\nTang KT\nInt J Rheum Dis\n2022 Mar;25(3):327-334.\nEpub 2022 Jan 7\ndoi: 10.1111/1756-185X.14272.\nPMID: 34994523\n\nEvidence-based clinical practice guidelines for Liver Cirrhosis 2020.\nYoshiji H,\nNagoshi S,\nAkahane T,\nAsaoka Y,\nUeno Y,\nOgawa K,\nKawaguchi T,\nKurosaki M,\nSakaida I,\nShimizu M,\nTaniai M,\nTerai S,\nNishikawa H,\nHiasa Y,\nHidaka H,\nMiwa H,\nChayama K,\nEnomoto N,\nShimosegawa T,\nTakehara T,\nKoike K\nJ Gastroenterol\n2021 Jul;56(7):593-619.\nEpub 2021 Jul 7\ndoi: 10.1007/s00535-021-01788-x.\nPMID: 34231046Free PMC Article\n\nAssociation of lipid profile with decompensation, liver dysfunction, and mortality in patients with liver cirrhosis.\nFeng R,\nGuo X,\nKou Y,\nXu X,\nHong C,\nZhang W,\nAn Y,\nPhilips CA,\nMancuso A,\nQi X\nPostgrad Med\n2021 Aug;133(6):626-638.\nEpub 2021 Jun 16\ndoi: 10.1080/00325481.2021.1930560.\nPMID: 33993838\nSee all (32081)\nTherapy\nMetabolomic changes after DAAs therapy are related to the improvement of cirrhosis and inflammation in HIV/HCV-coinfected patients.\nVirseda-Berdices A,\nRojo D,\nMartínez I,\nBerenguer J,\nGonzález-García J,\nBrochado-Kith O,\nFernández-Rodríguez A,\nDíez C,\nHontañon V,\nPérez-Latorre L,\nMicán R,\nBarbas C,\nResino S,\nJiménez-Sousa MA;\nESCORIAL Study Group.\nBiomed Pharmacother\n2022 Mar;147:112623.\nEpub 2022 Jan 12\ndoi: 10.1016/j.biopha.2022.112623.\nPMID: 35032770\n\nAssociation of tumor necrosis factor-α inhibitors and liver cirrhosis in patients with rheumatoid arthritis: A nationwide population-based nes ...
#   'source_name': 'In-patient Expenditure Between 2012 and 2020 Concerning Patients With Liver Cirrhosis in Chongqing: A Hospital-Based Multicenter Retrospective Study.',
#   'source_link': '/pubmed/35350474',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C1623038'},
#  {'disease': 'exanthema',
#   'code': 'C0015230',
#   'description': 'A red eruption of the skin. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0015230'},
#  {'disease': 'benign prostatic hypertrophy',
#   'code': 'C0005001',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0005001'},
#  {'disease': 'kidney failure acute',
#   'code': 'C0022660',
#   'description': 'Sudden and sustained deterioration of the kidney function characterized by decreased glomerular filtration rate, increased serum creatinine or oliguria. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0022660'},
#  {'disease': 'mitral valve insufficiency',
#   'code': 'C0026266',
#   'description': 'An abnormality of the mitral valve characterized by insufficiency or incompetence of the mitral valve resulting in retrograde leaking of blood through the mitral valve upon ventricular contraction. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0026266'},
#  {'disease': 'arthritis',
#   'code': 'C0003864',
#   'description': 'Inflammation of a joint. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0003864'},
#  {'disease': 'bronchitis',
#   'code': 'C0006277',
#   'description': 'Inflammation of the large airways in the lung including any part of the bronchi from the primary bronchi to the tertiary bronchi. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0006277'},
#  {'disease': 'hemiparesis',
#   'code': 'C0018989',
#   'description': 'Loss of strength in the arm, leg, and sometimes face on one side of the body. Hemiplegia refers to a complete loss of strength, whereas hemiparesis refers to an incomplete loss of strength. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0018989'},
#  {'disease': 'osteoporosis',
#   'code': 'C0029456',
#   'description': 'Osteoporosis is a systemic skeletal disease characterized by low bone density and microarchitectural deterioration of bone tissue with a consequent increase in bone fragility. According to the WHO criteria, osteoporosis is defined as a BMD that lies 2.5 standard deviations or more below the average value for young healthy adults (a T-score below -2.5 SD). [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0029456'},
#  {'disease': 'transient ischemic attack',
#   'code': 'C0007787',
#   'description': 'A brief attack (from a few minutes to an hour) of cerebral dysfunction of vascular origin, with no persistent neurological deficit. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0007787'},
#  {'disease': 'adenocarcinoma',
#   'code': 'C0001418',
#   'description': 'A common cancer characterized by the presence of malignant glandular cells. Morphologically, adenocarcinomas are classified according to the growth pattern (e.g., papillary, alveolar) or according to the secreting product (e.g., mucinous, serous). Representative examples of adenocarcinoma are ductal and lobular breast carcinoma, lung adenocarcinoma, renal cell carcinoma, hepatocellular carcinoma (hepatoma), colon adenocarcinoma, and prostate adenocarcinoma. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0001418'},
#  {'disease': 'paranoia',
#   'code': 'C1456784',
#   'description': 'A persecutory delusion of supposed hostility of others. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C1456784'},
#  {'disease': 'pancreatitis',
#   'code': 'C0030305',
#   'description': 'The presence of inflammation in the pancreas. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0030305'},
#  {'disease': 'incontinence',
#   'code': 'C0021167',
#   'description': 'Involuntary passage of stool or urine from the body. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0021167'},
#  {'disease': 'paroxysmal dyspnea',
#   'code': 'C0013405',
#   'description': 'A sudden attack of dyspnea that occurs while the affected person is at rest. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0013405'},
#  {'disease': 'hernia',
#   'code': 'C0019270',
#   'description': 'The protrusion of part of an organ or fibroadipose tissue through an abnormal opening. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0019270'},
#  {'disease': 'malignant neoplasm of prostate',
#   'code': 'C0376358',
#   'description': 'A cancer of the prostate. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0376358'},
#  {'disease': 'carcinoma prostate',
#   'code': 'C0600139',
#   'description': 'One of the most common malignant tumors afflicting men. The majority of carcinomas arise in the peripheral zone and a minority occur in the central or the transitional zone of the prostate gland. Grossly, prostatic carcinomas appear as ill-defined yellow areas of discoloration in the prostate gland lobes. Adenocarcinomas represent the overwhelming majority of prostatic carcinomas. Prostatic-specific antigen (PSA) serum test is widely used as a screening test for the early detection of prostatic carcinoma. Treatment options include radical prostatectomy, radiation therapy, androgen ablation and cryotherapy. Watchful waiting or surveillance alone is an option for older patients with low-grade or low-stage disease. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0600139'},
#  {'disease': 'edema pulmonary',
#   'code': 'C0034063',
#   'description': 'Fluid accumulation in the lungs. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0034063'},
#  {'disease': 'lymphatic diseases',
#   'code': 'C0024228',
#   'description': 'Diseases of LYMPH; LYMPH NODES; or LYMPHATIC VESSELS. [from MeSH]',
#   'source_name': 'MeSH',
#   'source_link': 'http://www.nlm.nih.gov/pubs/factsheets/mesh.html',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0024228'},
#  {'disease': 'stenosis aortic valve',
#   'code': 'C0003507',
#   'description': 'The presence of a stenosis (narrowing) of the aortic valve. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0003507'},
#  {'disease': 'malignant neoplasm of breast',
#   'code': 'C0006142',
#   'description': 'Breast cancer is a disease in which certain cells in the breast become abnormal and multiply uncontrollably to form a tumor. Although breast cancer is much more common in women, this form of cancer can also develop in men.  In both women and men, the most common form of breast cancer begins in cells lining the milk ducts (ductal cancer). In women, cancer can also develop in the glands that produce milk (lobular cancer). Most men have little or no lobular tissue, so lobular cancer in men is very rare. \\n\\nIn its early stages, breast cancer usually does not cause pain and may exhibit no noticeable symptoms. As the cancer progresses, signs and symptoms can include a lump or thickening in or near the breast; a change in the size or shape of the breast; nipple discharge, tenderness, or retraction (turning inward); and skin irritation, dimpling, redness, or scaliness. However, these changes can occur as part of many different conditions. Having one or more of these symptoms does not mean that a person definitely has breast cancer.\\n\\nIn some cases, cancerous cells can invade surrounding breast tissue. In these cases, the condition is known as invasive breast cancer. Sometimes, tumors spread to other parts of the body. If breast cancer spreads, cancerous cells most often appear in the bones, liver, lungs, or brain. Tumors that begin at one site and then spread to other areas of the body are called metastatic cancers.\\n\\nA small percentage of all breast cancers cluster in families. These cancers are described as hereditary and are associated with inherited gene mutations. Hereditary breast cancers tend to develop earlier in life than noninherited (sporadic) cases, and new (primary) tumors are more likely to develop in both breasts. [from MedlinePlus Genetics]',
#   'source_name': 'MedlinePlus Genetics',
#   'source_link': 'https://medlineplus.gov/genetics/',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0006142'},
#  {'disease': 'carcinoma breast',
#   'code': 'C0678222',
#   'description': 'The presence of a carcinoma of the breast. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0678222'},
#  {'disease': 'schizophrenia',
#   'code': 'C0036341',
#   'description': 'Schizophrenia is highly heritable, as shown by family, twin, and adoption studies. For example, for identical twins, if one twin develops schizophrenia, the other twin has about a 50% chance of also developing the disease. The risk of the general population developing the schizophrenia is about 0.3-0.7% worldwide. The search for “schizophrenia genes” has been elusive. Initial linkage studies looked at parts of the genome associated with schizophrenia, and many candidate genes were identified, including APOE, COMT, DAO, DRD1, DRD2, DRD4, DTNBP1, GABRB2, GRIN2B, HP, IL1B, MTHFR, PLXNA2, SLC6A4, TP53, and TPH1. However, some of these have later been questioned. Microdeletions and microduplications have been found to be three times more common in individuals with schizophrenia, compared to controls. Because these deletions and duplications are in genes that are overexpressed in pathways related to brain development, it is possible that the inheritance of multiple rare variants may contribute to the development of schizophrenia. Several genetic disorders feature schizophrenia as a clinical feature. The 22q11.2 Deletion Syndrome comprises many different syndromes, of which one of the most serious is DiGeorge syndrome. Children born with DiGeorge syndrome typically have heart defects, cleft palate, learning difficulties, and immune deficiency. Schizophrenia is a late manifestation, affecting around 30% of individuals. Microdeletions and duplications in chromosome 1, 2, 3, 7, 15 and 16 have also been associated with schizophrenia. In 2014, a genome-wide association study looked at the genomes of over 35,000 patients and 110,00 controls. The study identified 108 SNPs that were associated with schizophrenia, 83 of which had not been previously reported. As expected, many of these loci occurred in genes that are expressed in the brain. For example, the SNPs included a gene that encodes the dopamine D2 receptor, DRD2 (the target of antipsychotic drugs), and many genes involved in glutamine neurotransmitter pathways and synaptic plasticity (e.g., GRM3, GRIN2A, SRR, GRIA1). More surprisingly, however, associations were also enriched among genes expressed in tissues with important immune functions. In 2016, a study based on nearly 65,000 people investigated the association between schizophrenia and variation in the Major Histocompatibility Complex (MHC) locus—a region on chromosome 6 that is important for immune function. The study focused on the C4 gene (complement component 4) that exists as two distinct genes: C4A and C4B, which encode particularly structurally diverse alleles. The study found that the alleles which promoted greater expression of C4A in the brain were associated with a greater risk of schizophrenia. By using mice models, the study showed that C4 is involved in the elimination of synapses during brain maturation. In humans, “synaptic pruning” is most active during late adolescence, which coincides with the typical onset of symptoms of schizophrenia. It is therefore possible that the inheritance of specific C4A alleles could lead to “run away” synaptic pruning, increasing the risk of schizophrenia. Further research may even determine C4 as a potential therapeutic target. [from Medical Genetics Summaries]',
#   'source_name': 'Medical Genetics Summaries',
#   'source_link': 'https://www.ncbi.nlm.nih.gov/books/NBK61999',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0036341'},
#  {'disease': 'diverticulitis',
#   'code': 'C0012813',
#   'description': 'An infection that develops in the diverticula of the intestinal tract. Signs and symptoms include abdominal pain, fever, and leukocytosis. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0012813'},
#  {'disease': 'overload fluid',
#   'code': 'C0546817',
#   'description': 'An increase in the amount of intravascular fluid, particularly in the volume of the circulating blood. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0546817'},
#  {'disease': 'ulcer peptic',
#   'code': 'C0030920',
#   'description': 'An ulcer of the gastrointestinal tract. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0030920'},
#  {'disease': 'osteomyelitis',
#   'code': 'C0029443',
#   'description': 'Osteomyelitis is an inflammatory process accompanied by bone destruction and caused by an infecting microorganism. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0029443'},
#  {'disease': 'gastritis',
#   'code': 'C0017152',
#   'description': 'The presence of inflammation of the gastric mucous membrane. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0017152'},
#  {'disease': 'bacteremia',
#   'code': 'C0004610',
#   'description': 'Presence of viable bacteria in the blood. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0004610'},
#  {'disease': 'failure kidney',
#   'code': 'C0035078',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0035078'},
#  {'disease': 'sickle cell anemia',
#   'code': 'C0002895',
#   'description': 'Excerpted from the GeneReview: Sickle Cell DiseaseSickle cell disease (SCD) is characterized by intermittent vaso-occlusive events and chronic hemolytic anemia. Vaso-occlusive events result in tissue ischemia leading to acute and chronic pain as well as organ damage that can affect any organ system, including the bones, spleen, liver, brain, lungs, kidneys, and joints. Dactylitis (pain and/or swelling of the hands or feet) is often the earliest manifestation of SCD. In children, the spleen can become engorged with blood cells in a "splenic sequestration." The spleen is particularly vulnerable to infarction and the majority of individuals with SCD who are not on hydroxyurea or transfusion therapy become functionally asplenic in early childhood, increasing their risk for certain types of bacterial infections. Acute chest syndrome is a major cause of mortality in SCD. Chronic hemolysis can result in varying degrees of anemia, jaundice, cholelithiasis, and delayed growth and sexual maturation. Individuals with the highest rates of hemolysis are predisposed to pulmonary artery hypertension, priapism, and leg ulcers but may be relatively protected from vaso-occlusive pain. [from GeneReviews]Full text of GeneReview (by section):Summary  |  GeneReview Scope  |  Diagnosis  |  Clinical Characteristics  |  Genetically Related (Allelic) Disorders  |  Differential Diagnosis  |  Management  |  Genetic Counseling  |  Resources  |  Molecular Genetics  |  Chapter Notes  |  ReferencesAuthors:\n MA Bender   view full author information',
#   'source_name': 'Sickle Cell Disease',
#   'source_link': '/books/NBK1377',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0002895'},
#  {'disease': 'failure heart',
#   'code': 'C0018801',
#   'description': 'Inability of the heart to pump blood at an adequate rate to meet tissue metabolic requirements. Clinical symptoms of heart failure include: unusual dyspnea on light exertion, recurrent dyspnea occurring in the supine position, fluid retention or rales, jugular venous distension, pulmonary edema on physical exam, or pulmonary edema on chest x-ray presumed to be cardiac dysfunction. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0018801'},
#  {'disease': 'upper respiratory infection',
#   'code': 'C0041912',
#   'description': 'An infectious process affecting the upper respiratory tract (nose, paranasal sinuses, pharynx, larynx, or trachea). Symptoms include congestion, sneezing, coughing, fever, and sore throat. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0041912'},
#  {'disease': 'hepatitis',
#   'code': 'C0019158',
#   'description': 'Inflammation of the liver. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0019158'},
#  {'disease': 'hypertension pulmonary',
#   'code': 'C0020542',
#   'description': 'Increased pressure within the pulmonary circulation due to lung or heart disorder. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0020542'},
#  {'disease': 'deglutition disorder',
#   'code': 'C0011168',
#   'description': 'Difficulty in swallowing. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0011168'},
#  {'disease': 'gout',
#   'code': 'C0018099',
#   'description': 'Recurrent attacks of acute inflammatory arthritis of a joint or set of joints caused by elevated levels of uric acid in the blood which crystallize and are deposited in joints, tendons, and surrounding tissues. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0018099'},
#  {'disease': 'thrombocytopaenia',
#   'code': 'C0040034',
#   'description': 'A reduction in the number of circulating thrombocytes. [from HPO]',
#   'source_name': 'HPO',
# ...
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0034186'},
#  {'disease': 'endocarditis',
#   'code': 'C0014118',
#   'description': 'An inflammation of the endocardium, the inner layer of the heart, which usually involves the heart valves. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0014118'},
#  {'disease': 'effusion pericardial',
#   'code': 'C0031039',
#   'description': 'Accumulation of fluid within the pericardium. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0031039'},
#  {'disease': 'pericardial effusion body substance',
#   'code': 'C1253937',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C1253937'},
#  {'disease': 'chronic alcoholic intoxication',
#   'code': 'C0001973',
#   'description': 'Alcohol use disorder is a diagnosis made when an individual has severe problems related to drinking alcohol. Alcohol use disorder can cause major health, social, and economic problems, and can endanger affected individuals and others through behaviors prompted by impaired decision-making and lowered inhibitions, such as aggression, unprotected sex, or driving while intoxicated.\\n\\nAlcohol use disorder is a broad diagnosis that encompasses several commonly used terms describing problems with drinking. It includes alcoholism, also called alcohol addiction, which is a long-lasting (chronic) condition characterized by a powerful, compulsive urge to drink alcohol and the inability to stop drinking after starting. In addition to alcoholism, alcohol use disorder includes alcohol abuse, which involves problem drinking without addiction.\\n\\nHabitual excessive use of alcohol changes the chemistry of the brain and leads to tolerance, which means that over time the amount of alcohol ingested needs to be increased to achieve the same effect. Long-term excessive use of alcohol may also produce dependence, which means that when people stop drinking, they have physical and psychological symptoms of withdrawal, such as sleep problems, irritability, jumpiness, shakiness, restlessness, headache, nausea, sweating, anxiety, and depression. In severe cases, agitation, fever, seizures, and hallucinations can occur; this pattern of severe withdrawal symptoms is called delirium tremens.\\n\\nThe heavy drinking that often occurs in alcohol use disorder, and can also occur in short-term episodes called binge drinking, can lead to a life-threatening overdose known as alcohol poisoning. Alcohol poisoning occurs when a large quantity of alcohol consumed over a short time causes problems with breathing, heart rate, body temperature, and the gag reflex. Signs and symptoms can include vomiting, choking, confusion, slow or irregular breathing, pale or blue-tinged skin, seizures, a low body temperature, a toxic buildup of substances called ketones in the blood (alcoholic ketoacidosis), and passing out (unconsciousness). Coma, brain damage, and death can occur if alcohol poisoning is not treated immediately.\\n\\nChronic heavy alcohol use can also cause long-term problems affecting many organs and systems of the body. These health problems include irreversible liver disease (cirrhosis), inflammation of the pancreas (pancreatitis), brain dysfunction (encephalopathy), nerve damage (neuropathy), high blood pressure (hypertension), stroke, weakening of the heart muscle (cardiomyopathy), irregular heartbeats (arrhythmia), and immune system problems. Long-term overuse of alcohol also increases the risk of certain cancers, including cancers of the mouth, throat, esophagus, liver, and breast. Alcohol use in pregnant women can cause birth defects and fetal alcohol syndrome, which can lead to lifelong physical and behavioral problems in the affected child. [from MedlinePlus Genetics]',
#   'source_name': 'MedlinePlus Genetics',
#   'source_link': 'https://medlineplus.gov/genetics/',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0001973'},
#  {'disease': 'pneumothorax',
#   'code': 'C0032326',
#   'description': 'Accumulation of air in the pleural cavity leading to a partially or completely collapsed lung. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0032326'},
#  {'disease': 'delirium',
#   'code': 'C0011206',
#   'description': 'A state of sudden and severe confusion. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0011206'},
#  {'disease': 'neutropenia',
#   'code': 'C0027947',
#   'description': 'A decrease in the number of NEUTROPHILS found in the blood. [from MeSH]',
#   'source_name': 'MeSH',
#   'source_link': 'http://www.nlm.nih.gov/pubs/factsheets/mesh.html',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0027947'},
#  {'disease': 'hyperbilirubinemia',
#   'code': 'C0020433',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0020433'},
#  {'disease': 'influenza',
#   'code': 'C0021400',
#   'description': 'An acute viral infection of the respiratory tract, occurring in isolated cases, in epidemics, or in pandemics; it is caused by serologically different strains of viruses (influenzaviruses) designated A, B, and C, has a 3-day incubation period, and usually lasts for 3 to 10 days. It is marked by inflammation of the nasal mucosa, pharynx, and conjunctiva; headache; myalgia; often fever, chills, and prostration; and occasionally involvement of the myocardium or central nervous system. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0021400'},
#  {'disease': 'dependence',
#   'code': 'C0439857',
#   'description': 'The psychological or physiological need to take a substance in order to experience its effects or to avoid the effects of its absence. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0439857'},
#  {'disease': 'thrombus',
#   'code': 'C0087086',
#   'description': 'Etiology\nSystemic Immune-Inflammation Index: A Novel Predictor of Coronary Thrombus Burden in Patients with Non-ST Acute Coronary Syndrome.\nÖzkan U,\nGürdoğan M,\nÖztürk C,\nDemir M,\nAkkuş ÖF,\nYılmaz E,\nAltay S\nMedicina (Kaunas)\n2022 Jan 18;58(2)\ndoi: 10.3390/medicina58020143.\nPMID: 35208466Free PMC Article\n\nStep-by-step and orderly lowering of the height of inferior vena cava tumor thrombus is the key to robot-assisted thrombectomy for Mayo III/IV tumor thrombus.\nZhao GD,\nZhang XP,\nHu MG,\nHuang QB,\nXu S,\nWang BJ,\nMa X,\nZhang X,\nZou WB,\nZhang X,\nZhao ZM,\nTan XL,\nChou S,\nWang G,\nLiu R\nBMC Cancer\n2022 Feb 7;22(1):151.\ndoi: 10.1186/s12885-022-09235-7.\nPMID: 35130848Free PMC Article\n\nContinuum modeling of thrombus formation and growth under different shear rates.\nRezaeimoghaddam M,\nvan de Vosse FN\nJ Biomech\n2022 Feb;132:110915.\nEpub 2022 Jan 4\ndoi: 10.1016/j.jbiomech.2021.110915.\nPMID: 35032838\n\nA New Score for Determining Thrombus Burden in STEMI Patients: The MAPH Score.\nAbacioglu OO,\nYildirim A,\nKaradeniz M,\nAbacioglu S,\nKoyunsever NY,\nDindas F,\nDogdus M,\nKaplangoray M\nClin Appl Thromb Hemost\n2022 Jan-Dec;28:10760296211073767.\ndoi: 10.1177/10760296211073767.\nPMID: 35018837Free PMC Article\n\nRenal cell carcinoma with tumor thrombus growing against the direction of venous return: an indicator of complicated surgery and poor prognosis.\nLiu Z,\nLi Y,\nZhao X,\nGe L,\nZhu G,\nHong P,\nTang S,\nZhang S,\nTian X,\nWang S,\nLiu C,\nZhang H,\nMa L\nBMC Surg\n2021 Dec 28;21(1):443.\ndoi: 10.1186/s12893-021-01448-0.\nPMID: 34963464Free PMC Article\nSee all (12007)\nDiagnosis\nSystemic Immune-Inflammation Index: A Novel Predictor of Coronary Thrombus Burden in Patients with Non-ST Acute Coronary Syndrome.\nÖzkan U,\nGürdoğan M,\nÖztürk C,\nDemir M,\nAkkuş ÖF,\nYılmaz E,\nAltay S\nMedicina (Kaunas)\n2022 Jan 18;58(2)\ndoi: 10.3390/medicina58020143.\nPMID: 35208466Free PMC Article\n\nA New Score for Determining Thrombus Burden in STEMI Patients: The MAPH Score.\nAbacioglu OO,\nYildirim A,\nKaradeniz M,\nAbacioglu S,\nKoyunsever NY,\nDindas F,\nDogdus M,\nKaplangoray M\nClin Appl Thromb Hemost\n2022 Jan-Dec;28:10760296211073767.\ndoi: 10.1177/10760296211073767.\nPMID: 35018837Free PMC Article\n\nRole of anticoagulation in the management of tumor thrombus: A 10-year single-center experience.\nAgarwal S,\nMullikin D,\nScheurer ME,\nSmith V,\nNaik-Mathuria B,\nGuillerman RP,\nFoster JH,\nDiaz R,\nSartain SE\nPediatr Blood Cancer\n2021 Sep;68(9):e29173.\nEpub 2021 Jun 1\ndoi: 10.1002/pbc.29173.\nPMID: 34061441\n\nNovel application of indocyanine green fluorescence imaging for real-time detection of thrombus in a membrane oxygenator.\nSakurai H,\nFujiwara T,\nOhuchi K,\nHijikata W,\nInoue Y,\nSeki H,\nTahara T,\nYokota S,\nOgata A,\nMizuno T,\nArai H\nArtif Organs\n2021 Oct;45(10):1173-1182.\nEpub 2021 Jun 12\ndoi: 10.1111/aor.13999.\nPMID: 34037247\n\nPolarimetric Signatures of Coronary Thrombus in Patients With Acute Coronary Syndrome.\nvan Zandvoort LJC,\nOtsuka K,\nVilliger M,\nNeleman T,\nDijkstra J,\nZijlstra F,\nvan Mieghem NM,\nBouma BE,\nDaemen J\nCirc J\n2021 Sep 24;85(10):1806-1813.\nEpub 2021 Apr 7\ndoi: 10.1253/circj.CJ-20-0862.\nPMID: 33828020\nSee all (10017)\nTherapy\nThrombus-targeted nanoparticles for thrombin-triggered thrombolysis and local inflammatory microenvironment regulation.\nZhang H,\nQu H,\nHe Q,\nGao L,\nZhang H,\nWang Y,\nZhang Z,\nHou L\nJ Control Release\n2021 Nov 10;339:195-207.\nEpub 2021 Jun 29\ndoi: 10.1016/j.jconrel.2021.06.043.\nPMID: 34214595\n\nRole of anticoagulation in the management of tumor thrombus: A 10-year single-center experience.\nAgarwal S,\nMullikin D,\nScheurer ME,\nSmith V,\nNaik-Mathuria B,\nGuillerman RP,\nFoster JH,\nDiaz R,\nSartain SE\nPediatr Blood Cancer\n2021 Sep;68(9):e29173.\nEpub 2021 Jun 1\ndoi: 10.1002/pbc.29173.\nPMID: 34061441\n\nNovel application of indocyanine green fluorescence imaging for real-time dete ...
#   'source_name': 'Systemic Immune-Inflammation Index: A Novel Predictor of Coronary Thrombus Burden in Patients with Non-ST Acute Coronary Syndrome.',
#   'source_link': '/pubmed/35208466',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0087086'},
#  {'disease': 'cholecystitis',
#   'code': 'C0008325',
#   'description': 'The presence of inflammatory changes in the gallbladder. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0008325'},
#  {'disease': 'hernia hiatal',
#   'code': 'C0019291',
#   'description': None,
#   'source_name': None,
#   'source_link': None,
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0019291'},
#  {'disease': 'migraine disorders',
#   'code': 'C0149931',
#   'description': 'Migraine is the most common type of chronic, episodic headache, as summarized by Featherstone (1985).\r One locus for migraine with or without aura (MGR1) has been identified on chromosome 4q24. Other loci for migraine have been identified on 6p21.1-p12.2 (MGR3; 607498), 14q21.2-q22.3 (MGR4; 607501), 19p13 (MGR5; 607508), 1q31 (MGR6; 607516), 15q11-q13 (MGR7; 609179), 5q21 (with or without aura, MGR8, 609570; with aura, MGR9, 609670), 17p13 (MGR10; 610208), 18q12 (MGR11; 610209), 10q22-q23 (MGR12; 611706), and the X chromosome (MGR2; 300125).\r Mutation in the KCNK18 gene (613655) on chromosome 10q25 causes migraine with aura (MGR13; 613656).\r A subtype of autosomal dominant migraine with aura (MA), familial hemiplegic migraine (FHM; see 141500), is caused by mutation in the CACNA1A gene (601011) on chromosome 19p13 (FHM1; 141500), by mutation in the ATP1A2 gene (182340) on chromosome 1q21 (FHM2; 602481), or by mutation in the SCN1A gene (182389) on chromosome 2q24 (FHM3; 609634). Another locus for FHM has been mapped to chromosome 1q31 (FHM4; see 607516).\r There is evidence that a polymorphism in the estrogen receptor gene (ESR1; 133430.0005) and a polymorphism in the TNF gene (191160.0004) may confer susceptibility to migraine. A polymorphism in the endothelin receptor type A gene (EDNRA; 131243.0001) may confer resistance to migraine. [from OMIM]',
#   'source_name': 'OMIM',
#   'source_link': 'http://www.omim.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0149931'},
#  {'disease': 'pancytopenia',
#   'code': 'C0030312',
#   'description': 'An abnormal reduction in numbers of all blood cell types (red blood cells, white blood cells, and platelets). [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0030312'},
#  {'disease': 'cholelithiasis',
#   'code': 'C0008350',
#   'description': 'Hard, pebble-like deposits that form within the gallbladder. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0008350'},
#  {'disease': 'biliary calculus',
#   'code': 'C0242216',
#   'description': 'Solid crystalline precipitates in the biliary tract, usually formed in the gallbladder, resulting in the condition of cholelithiasis. Gallstones, derived from the bile, consist mainly of calcium, cholesterol, or bilirubin. [from MONDO]',
#   'source_name': 'MONDO',
#   'source_link': 'https://monarchinitiative.org/',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0242216'},
#  {'disease': 'tachycardia sinus',
#   'code': 'C0039239',
#   'description': 'Heart rate of greater than 100 beats per minute. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0039239'},
#  {'disease': 'ileus',
#   'code': 'C1258215',
#   'description': 'Acute obstruction of the intestines preventing passage of the contents of the intestines. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C1258215'},
#  {'disease': 'adhesion',
#   'code': 'C0001511',
#   'description': 'A fibrous band of tissue that connects normally separate body regions. [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0001511'},
#  {'disease': 'delusion',
#   'code': 'C0011253',
#   'description': 'A false belief that is held despite evidence to the contrary. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0011253'},
#  {'disease': 'affect labile',
#   'code': 'C0233472',
#   'description': 'Emotional instability characterized by rapid and dramatic mood swings. (ACC-AHA) [from NCI]',
#   'source_name': 'NCI',
#   'source_link': 'http://ncit.nci.nih.gov',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0233472'},
#  {'disease': 'decubitus ulcer',
#   'code': 'C0011127',
#   'description': 'A type of ulcer that is caused when an area of skin is subject to pressure over a prolonged period of time, ranging in range in severity from patches of discolored skin to open wounds that expose the underlying bone or muscle. The most common sites are the sacrum, coccyx, heels and the hips. [from HPO]',
#   'source_name': 'HPO',
#   'source_link': 'http://www.human-phenotype-ontology.org',
#   'root_url': 'https://www.ncbi.nlm.nih.gov/medgen/?term=C0011127'}]

# %% [markdown]
# Converting the dictionary into a data frame.

# %%
disease_code_df = pd.DataFrame(disease_data)
disease_code_df
# Out:
#                        disease      code  \
# 0         hypertensive disease  C0020538
# 1                     diabetes  C0011847
# 2            depression mental  C0011570
# 3          depressive disorder  C0011581
# 4    coronary arteriosclerosis  C0010054
# ..                         ...       ...
# 144                      ileus  C1258215
# 145                   adhesion  C0001511
# 146                   delusion  C0011253
# 147              affect labile  C0233472
# 148            decubitus ulcer  C0011127
#
#                                            description source_name  \
# 0    The presence of chronic increased pressure in ...         HPO
# 1                                                 None        None
# 2                                                 None        None
# 3    Frequent feelings of being down, miserable, an...         HPO
# 4    Reduction of the diameter of the coronary arte...         HPO
# ..                                                 ...         ...
# 144  Acute obstruction of the intestines preventing...         HPO
# 145  A fibrous band of tissue that connects normall...         NCI
# 146  A false belief that is held despite evidence t...         HPO
# 147  Emotional instability characterized by rapid a...         NCI
# 148  A type of ulcer that is caused when an area of...         HPO
#
#                                  source_link  \
# 0    http://www.human-phenotype-ontology.org
# 1                                       None
# 2                                       None
# 3    http://www.human-phenotype-ontology.org
# 4    http://www.human-phenotype-ontology.org
# ..                                       ...
# 144  http://www.human-phenotype-ontology.org
# 145                  http://ncit.nci.nih.gov
# 146  http://www.human-phenotype-ontology.org
# 147                  http://ncit.nci.nih.gov
# 148  http://www.human-phenotype-ontology.org
#
#                                               root_url
# 0    https://www.ncbi.nlm.nih.gov/medgen/?term=C002...
# 1    https://www.ncbi.nlm.nih.gov/medgen/?term=C001...
# 2    https://www.ncbi.nlm.nih.gov/medgen/?term=C001...
# 3    https://www.ncbi.nlm.nih.gov/medgen/?term=C001...
# 4    https://www.ncbi.nlm.nih.gov/medgen/?term=C001...
# ..                                                 ...
# 144  https://www.ncbi.nlm.nih.gov/medgen/?term=C125...
# 145  https://www.ncbi.nlm.nih.gov/medgen/?term=C000...
# 146  https://www.ncbi.nlm.nih.gov/medgen/?term=C001...
# 147  https://www.ncbi.nlm.nih.gov/medgen/?term=C023...
# 148  https://www.ncbi.nlm.nih.gov/medgen/?term=C001...
#
# [149 rows x 6 columns]

# %% [markdown]
# Save the data frame into CSV.

# %%
CSV_FILEPATH = 'dataset/disease-description.csv'
disease_code_df.to_csv(CSV_FILEPATH, index=False)
