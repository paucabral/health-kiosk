# %% [markdown]
# Importing the necessary libraries.

# %%
import csv
import numpy as np
import pandas as pd
from collections import defaultdict

# %% [markdown]
# Load the scraped dataset CSV file into a data frame.

# %%
CSV_FILEPATH = 'dataset/raw_data.csv'
data = pd.read_csv(CSV_FILEPATH)
data = data.replace({"  ": " "}, regex=True)
data
# Out:
#                                  Disease  Count of Disease  Occurrence  \
# 0     UMLS:C0020538_hypertensive disease                        3363.0
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
# ...                                  ...                           ...
# 1861                                 NaN                           NaN
# 1862                                 NaN                           NaN
# 1863       UMLS:C0011127_decubitus ulcer                          42.0
# 1864                                 NaN                           NaN
# 1865                                 NaN                           NaN
#
#                                               Symptom
# 0                            UMLS:C0008031_pain chest
# 1                   UMLS:C0392680_shortness of breath
# 2                             UMLS:C0012833_dizziness
# 3                              UMLS:C0004093_asthenia
# 4                                  UMLS:C0085639_fall
# ...                                               ...
# 1861  UMLS:C0425251_bedridden^UMLS:C0741453_bedridden
# 1862                         UMLS:C0242453_prostatism
# 1863                    UMLS:C0232257_systolic murmur
# 1864                              UMLS:C0871754_frail
# 1865                              UMLS:C0015967_fever
#
# [1866 rows x 3 columns]

# %% [markdown]
# Narrow the dataset to disease column.

# %%
data = data[['Disease']]
data
# Out:
#                                  Disease
# 0     UMLS:C0020538_hypertensive disease
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1861                                 NaN
# 1862                                 NaN
# 1863       UMLS:C0011127_decubitus ulcer
# 1864                                 NaN
# 1865                                 NaN
#
# [1866 rows x 1 columns]

# %% [markdown]
# Dropping the null values.

# %%
data = data.dropna()
data
# Out:
#                                                 Disease
# 0                    UMLS:C0020538_hypertensive disease
# 12                               UMLS:C0011847_diabetes
# 26    UMLS:C0011570_depression mental^UMLS:C0011581_...
# 47    UMLS:C0010054_coronary arteriosclerosis^UMLS:C...
# 56                              UMLS:C0032285_pneumonia
# ...                                                 ...
# 1806                                UMLS:C1258215_ileus
# 1821                             UMLS:C0001511_adhesion
# 1834                             UMLS:C0011253_delusion
# 1855                        UMLS:C0233472_affect labile
# 1863                      UMLS:C0011127_decubitus ulcer
#
# [134 rows x 1 columns]

# %% [markdown]
# Function to process the names of the entries.

# %%
def process_name(data):
  data_list = []
  data_name = data.replace('^', '_').split('_')
  n = 1
  for names in data_name:
    if n % 1 == 0:
      data_list.append(names)
    n += 1
  return data_list

# %%
disease_umls_code_pair = []
for idx, row in data.iterrows():
    # Extract the Disease Names and UMLS Codes.
    if (row['Disease'] != "\xc2\xa0") and (row['Disease'] != ""):
        disease = row['Disease']
        disease_list = process_name(data=disease)

        disease_names = []
        disease_codes = []

        disease_names.extend(disease_list[1::2])
        disease_codes.extend(disease_list[::2])

        for disease, code in zip(disease_names, disease_codes):
            entry = {'umls': code.split(':')[1], 'disease': disease}
            disease_umls_code_pair.append(entry)

disease_umls_code_pair
# Out:
# [{'umls': 'C0020538', 'disease': 'hypertensive disease'},
#  {'umls': 'C0011847', 'disease': 'diabetes'},
#  {'umls': 'C0011570', 'disease': 'depression mental'},
#  {'umls': 'C0011581', 'disease': 'depressive disorder'},
#  {'umls': 'C0010054', 'disease': 'coronary arteriosclerosis'},
#  {'umls': 'C0010068', 'disease': 'coronary heart disease'},
#  {'umls': 'C0032285', 'disease': 'pneumonia'},
#  {'umls': 'C0018802', 'disease': 'failure heart congestive'},
#  {'umls': 'C0038454', 'disease': 'accident cerebrovascular'},
#  {'umls': 'C0004096', 'disease': 'asthma'},
#  {'umls': 'C0027051', 'disease': 'myocardial infarction'},
#  {'umls': 'C0020443', 'disease': 'hypercholesterolemia'},
#  {'umls': 'C0021311', 'disease': 'infection'},
#  {'umls': 'C0042029', 'disease': 'infection urinary tract'},
#  {'umls': 'C0002871', 'disease': 'anemia'},
#  {'umls': 'C0024117', 'disease': 'chronic obstructive airway disease'},
#  {'umls': 'C0497327', 'disease': 'dementia'},
#  {'umls': 'C1565489', 'disease': 'insufficiency renal'},
#  {'umls': 'C0009676', 'disease': 'confusion'},
#  {'umls': 'C0029408', 'disease': 'degenerative polyarthritis'},
#  {'umls': 'C0020676', 'disease': 'hypothyroidism'},
#  {'umls': 'C0700613', 'disease': 'anxiety state'},
#  {'umls': 'C0006826', 'disease': 'malignant neoplasms'},
#  {'umls': 'C1306459', 'disease': 'primary malignant neoplasm'},
#  {'umls': 'C0001175', 'disease': 'acquired immuno-deficiency syndrome'},
#  {'umls': 'C0019682', 'disease': 'HIV'},
#  {'umls': 'C0019693', 'disease': 'hiv infections'},
#  {'umls': 'C0007642', 'disease': 'cellulitis'},
#  {'umls': 'C0017168', 'disease': 'gastroesophageal reflux disease'},
#  {'umls': 'C0036690', 'disease': 'septicemia'},
#  {'umls': 'C0243026', 'disease': 'systemic infection'},
#  {'umls': 'C1090821', 'disease': 'sepsis (invertebrate)'},
#  {'umls': 'C0149871', 'disease': 'deep vein thrombosis'},
#  {'umls': 'C0011175', 'disease': 'dehydration'},
#  {'umls': 'C0027651', 'disease': 'neoplasm'},
#  {'umls': 'C0034065', 'disease': 'embolism pulmonary'},
#  {'umls': 'C0014544', 'disease': 'epilepsy'},
#  {'umls': 'C0878544', 'disease': 'cardiomyopathy'},
#  {'umls': 'C0022661', 'disease': 'chronic kidney failure'},
#  {'umls': 'C0007097', 'disease': 'carcinoma'},
#  {'umls': 'C0019196', 'disease': 'hepatitis C'},
#  {'umls': 'C0085096', 'disease': 'peripheral vascular disease'},
#  {'umls': 'C0033975', 'disease': 'psychotic disorder'},
#  {'umls': 'C0020473', 'disease': 'hyperlipidemia'},
#  {'umls': 'C0005586', 'disease': 'bipolar disorder'},
#  {'umls': 'C0028754', 'disease': 'obesity'},
#  {'umls': 'C0022116', 'disease': 'ischemia'},
#  {'umls': 'C1623038', 'disease': 'cirrhosis'},
#  {'umls': 'C0015230', 'disease': 'exanthema'},
#  {'umls': 'C0005001', 'disease': 'benign prostatic hypertrophy'},
#  {'umls': 'C0022660', 'disease': 'kidney failure acute'},
#  {'umls': 'C0026266', 'disease': 'mitral valve insufficiency'},
#  {'umls': 'C0003864', 'disease': 'arthritis'},
#  {'umls': 'C0006277', 'disease': 'bronchitis'},
#  {'umls': 'C0018989', 'disease': 'hemiparesis'},
#  {'umls': 'C0029456', 'disease': 'osteoporosis'},
#  {'umls': 'C0007787', 'disease': 'transient ischemic attack'},
#  {'umls': 'C0001418', 'disease': 'adenocarcinoma'},
#  {'umls': 'C1456784', 'disease': 'paranoia'},
#  {'umls': 'C0030305', 'disease': 'pancreatitis'},
#  {'umls': 'C0021167', 'disease': 'incontinence'},
#  {'umls': 'C0013405', 'disease': 'paroxysmal dyspnea'},
#  {'umls': 'C0019270', 'disease': 'hernia'},
#  {'umls': 'C0376358', 'disease': 'malignant neoplasm of prostate'},
#  {'umls': 'C0600139', 'disease': 'carcinoma prostate'},
#  {'umls': 'C0034063', 'disease': 'edema pulmonary'},
#  {'umls': 'C0024228', 'disease': 'lymphatic diseases'},
#  {'umls': 'C0003507', 'disease': 'stenosis aortic valve'},
#  {'umls': 'C0006142', 'disease': 'malignant neoplasm of breast'},
#  {'umls': 'C0678222', 'disease': 'carcinoma breast'},
#  {'umls': 'C0036341', 'disease': 'schizophrenia'},
#  {'umls': 'C0012813', 'disease': 'diverticulitis'},
#  {'umls': 'C0546817', 'disease': 'overload fluid'},
#  {'umls': 'C0030920', 'disease': 'ulcer peptic'},
#  {'umls': 'C0029443', 'disease': 'osteomyelitis'},
#  {'umls': 'C0017152', 'disease': 'gastritis'},
#  {'umls': 'C0004610', 'disease': 'bacteremia'},
#  {'umls': 'C0035078', 'disease': 'failure kidney'},
#  {'umls': 'C0002895', 'disease': 'sickle cell anemia'},
#  {'umls': 'C0018801', 'disease': 'failure heart'},
#  {'umls': 'C0041912', 'disease': 'upper respiratory infection'},
#  {'umls': 'C0019158', 'disease': 'hepatitis'},
#  {'umls': 'C0020542', 'disease': 'hypertension pulmonary'},
#  {'umls': 'C0011168', 'disease': 'deglutition disorder'},
#  {'umls': 'C0018099', 'disease': 'gout'},
#  {'umls': 'C0040034', 'disease': 'thrombocytopaenia'},
#  {'umls': 'C0020615', 'disease': 'hypoglycemia'},
#  {'umls': 'C0032290', 'disease': 'pneumonia aspiration'},
#  {'umls': 'C0009319', 'disease': 'colitis'},
#  {'umls': 'C1510475', 'disease': 'diverticulosis'},
#  {'umls': 'C0038663', 'disease': 'suicide attempt'},
#  {'umls': 'C0032305', 'disease': 'Pneumocystis carinii pneumonia'},
#  {'umls': 'C0019163', 'disease': 'hepatitis B'},
#  {'umls': 'C0030567', 'disease': 'parkinson disease'},
#  {'umls': 'C0024299', 'disease': 'lymphoma'},
#  {'umls': 'C0020456', 'disease': 'hyperglycemia'},
#  {'umls': 'C0085584', 'disease': 'encephalopathy'},
#  {'umls': 'C0040961', 'disease': 'tricuspid valve insufficiency'},
#  {'umls': 'C0002395', 'disease': "Alzheimer's disease"},
#  {'umls': 'C0006840', 'disease': 'candidiasis'},
#  {'umls': 'C0006849', 'disease': 'oral candidiasis'},
#  {'umls': 'C0442874', 'disease': 'neuropathy'},
#  {'umls': 'C0022658', 'disease': 'kidney disease'},
#  {'umls': 'C0023267', 'disease': 'fibroid tumor'},
#  {'umls': 'C0017601', 'disease': 'glaucoma'},
#  {'umls': 'C0027627', 'disease': 'neoplasm metastasis'},
#  {'umls': 'C0007102', 'disease': 'malignant tumor of colon'},
#  {'umls': 'C0699790', 'disease': 'carcinoma colon'},
#  {'umls': 'C0011880', 'disease': 'ketoacidosis diabetic'},
#  {'umls': 'C0014549', 'disease': 'tonic-clonic epilepsy'},
#  {'umls': 'C0494475', 'disease': 'tonic-clonic seizures'},
#  {'umls': 'C0006826', 'disease': 'malignant neoplasms'},
#  {'umls': 'C1145670', 'disease': 'respiratory failure'},
#  {'umls': 'C0025202', 'disease': 'melanoma'},
#  {'umls': 'C0017160', 'disease': 'gastroenteritis'},
#  {'umls': 'C0242379', 'disease': 'malignant neoplasm of lung'},
#  {'umls': 'C0684249', 'disease': 'carcinoma of lung'},
#  {'umls': 'C0024713', 'disease': 'manic disorder'},
#  {'umls': 'C0031212', 'disease': 'personality disorder'},
#  {'umls': 'C0019204', 'disease': 'primary carcinoma of the liver cells'},
#  {'umls': 'C0034067', 'disease': 'emphysema pulmonary'},
#  {'umls': 'C0019112', 'disease': 'hemorrhoids'},
#  {'umls': 'C0006266', 'disease': 'spasm bronchial'},
#  {'umls': 'C0003537', 'disease': 'aphasia'},
#  {'umls': 'C0028756', 'disease': 'obesity morbid'},
#  {'umls': 'C0034186', 'disease': 'pyelonephritis'},
#  {'umls': 'C0014118', 'disease': 'endocarditis'},
#  {'umls': 'C0031039', 'disease': 'effusion pericardial'},
#  {'umls': 'C1253937', 'disease': 'pericardial effusion body substance'},
#  {'umls': 'C0001973', 'disease': 'chronic alcoholic intoxication'},
#  {'umls': 'C0032326', 'disease': 'pneumothorax'},
#  {'umls': 'C0011206', 'disease': 'delirium'},
#  {'umls': 'C0027947', 'disease': 'neutropenia'},
#  {'umls': 'C0020433', 'disease': 'hyperbilirubinemia'},
#  {'umls': 'C0021400', 'disease': 'influenza'},
#  {'umls': 'C0439857', 'disease': 'dependence'},
#  {'umls': 'C0087086', 'disease': 'thrombus'},
#  {'umls': 'C0008325', 'disease': 'cholecystitis'},
#  {'umls': 'C0019291', 'disease': 'hernia hiatal'},
#  {'umls': 'C0149931', 'disease': 'migraine disorders'},
#  {'umls': 'C0030312', 'disease': 'pancytopenia'},
#  {'umls': 'C0008350', 'disease': 'cholelithiasis'},
#  {'umls': 'C0242216', 'disease': 'biliary calculus'},
#  {'umls': 'C0039239', 'disease': 'tachycardia sinus'},
#  {'umls': 'C1258215', 'disease': 'ileus'},
#  {'umls': 'C0001511', 'disease': 'adhesion'},
#  {'umls': 'C0011253', 'disease': 'delusion'},
#  {'umls': 'C0233472', 'disease': 'affect labile'},
#  {'umls': 'C0011127', 'disease': 'decubitus ulcer'}]

# %% [markdown]
# Create a dataframe for UMLS and disease name pairs.

# %%
disease_code_df = pd.DataFrame(disease_umls_code_pair)
disease_code_df
# Out:
#          umls                    disease
# 0    C0020538       hypertensive disease
# 1    C0011847                   diabetes
# 2    C0011570          depression mental
# 3    C0011581        depressive disorder
# 4    C0010054  coronary arteriosclerosis
# ..        ...                        ...
# 144  C1258215                      ileus
# 145  C0001511                   adhesion
# 146  C0011253                   delusion
# 147  C0233472              affect labile
# 148  C0011127            decubitus ulcer
#
# [149 rows x 2 columns]

# %% [markdown]
# Saved the processed data.

# %%
CSV_FILEPATH = 'dataset/disease-umls-code_pairs.csv'
disease_code_df.to_csv(CSV_FILEPATH, index=False)
