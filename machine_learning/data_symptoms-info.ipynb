# %% [markdown]
# Importing the necessary libraries.

# %%
import pandas as pd

# %% [markdown]
# Load the `Excel` file for symptoms information.

# %%
EXCEL_FILEPATH = 'dataset/symptoms-list-en-ph.xlsx'
data = pd.read_excel(EXCEL_FILEPATH)
data
# Out:
#                 symptom                  en                ph  \
# 0       Heberden's node     Heberden's node   Heberden's node
# 1         Murphy's sign       Murphy's sign     Murphy's sign
# 2         Stahli's line       Stahli's line     Stahli's line
# 3         abdomen acute       abdomen acute  talamak na tiyan
# 4    abdominal bloating  abdominal bloating  paglobo ng tiyan
# ..                  ...                 ...               ...
# 440            wheezing            wheezing        humihingal
# 441            withdraw            withdraw         pagbabawi
# 442               worry               worry         mag-alala
# 443       yellow sputum       yellow sputum    dilaw na plema
# 444       yellow sputum       yellow sputum    dilaw na plema
#
#                                                en_desc  \
# 0    Heberden’s nodes are small, pea-sized bony gro...
# 1    Murphy’s sign is elicited in patients with acu...
# ...

# %% [markdown]
# Convert the data frame into a dictionary.

# %%
data.to_dict('index')
# Out:
# {0: {'symptom': "Heberden's node",
#   'en': "Heberden's node",
#   'ph': "Heberden's node",
#   'en_desc': 'Heberden’s nodes are small, pea-sized bony growths that occur on the joint closest to the tip of the finger, also called the distal interphalangeal joint.',
#   'ph_desc': "Ang Heberden's node ay maliliit, kasing laki ng gisantes na paglaki ng buto na nangyayari sa magkasanib na pinakamalapit sa dulo ng daliri, na tinatawag ding distal interphalangeal joint.",
#   'source': "['https://my.clevelandclinic.org/health/symptoms/21829-heberdens-nodes#:~:text=Heberden's%20nodes%20are%20small%20bony,limited%20motion%20in%20your%20hands.']"},
#  1: {'symptom': "Murphy's sign",
#   'en': "Murphy's sign",
#   'ph': "Murphy's sign",
#   'en_desc': 'Murphy’s sign is elicited in patients with acute cholecystitis by asking the patient to take in and hold a deep breath while palpating the right subcostal area. ',
# ...
